# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/deiner.souza/Documents/Selenium/Pratica/Relatorio_financeiro.csv")
df.head(5)
# Out:
#    Unnamed: 0                                    chave_nota  numero da nota  \
# 0           0  31250721238738000323550010000004061639199159             406
# 1           1  31250721238738000323550010000004071167666112             407
# 2           2  31250721238738000323550010000004081077109173             408
# 3           3  31250721238738000323550010000004091604204131             409
# 4           4  31250721238738000323550010000004101586683917             410
#
#                    valor da nota  \
# 0  \n            45,60\n
# 1  \n            60,00\n
# 2  \n            54,40\n
# 3  \n            59,20\n
# 4  \n            98,00\n
#
#                                                 CFOP
# 0  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 1  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 2  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 3  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 4  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                      chave_nota  numero da nota  \
# 0  31250721238738000323550010000004061639199159             406
# 1  31250721238738000323550010000004071167666112             407
# 2  31250721238738000323550010000004081077109173             408
# 3  31250721238738000323550010000004091604204131             409
# 4  31250721238738000323550010000004101586683917             410
#
#                    valor da nota  \
# 0  \n            45,60\n
# 1  \n            60,00\n
# 2  \n            54,40\n
# 3  \n            59,20\n
# 4  \n            98,00\n
#
#                                                 CFOP
# 0  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 1  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 2  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 3  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 4  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...

# %%
df.columns = ["CHAVE", "NUMERO", "VALOR","CFOP"]

# %%
df.head()
# Out:
#                                           CHAVE  NUMERO  \
# 0  31250721238738000323550010000004061639199159     406
# 1  31250721238738000323550010000004071167666112     407
# 2  31250721238738000323550010000004081077109173     408
# 3  31250721238738000323550010000004091604204131     409
# 4  31250721238738000323550010000004101586683917     410
#
#                            VALOR  \
# 0  \n            45,60\n
# 1  \n            60,00\n
# 2  \n            54,40\n
# 3  \n            59,20\n
# 4  \n            98,00\n
#
#                                                 CFOP
# 0  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 1  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 2  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 3  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 4  5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...

# %%
df.loc[df["VALOR"] == r""]
